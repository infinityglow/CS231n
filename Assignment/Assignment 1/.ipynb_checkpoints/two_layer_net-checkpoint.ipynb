# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720496109664e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 0.018965419606063127

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W1 max relative error: 3.561318e-09
# W2 max relative error: 3.440708e-09
# b1 max relative error: 2.738422e-09
# b2 max relative error: 4.447687e-11

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.017143643532923816

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=400,
            learning_rate=1e-3, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302772
# iteration 100 / 1000: loss 1.905813
# iteration 200 / 1000: loss 1.817347
# iteration 300 / 1000: loss 1.653104
# iteration 400 / 1000: loss 1.611264
# iteration 500 / 1000: loss 1.545224
# iteration 600 / 1000: loss 1.575550
# iteration 700 / 1000: loss 1.486100
# iteration 800 / 1000: loss 1.446618
# iteration 900 / 1000: loss 1.456727
# Validation accuracy:  0.479

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 
best_acc = 0

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
l_rate = [-4, -3, -2, -1]
l_rate_decay = [0.9, 0.99, 0.999]
h_size = [50, 100, 200]
b_size = [32, 64, 128]
for lr in l_rate:
    for lr_decay in l_rate_decay:
        for hs in h_size:
            for bs in b_size:
                print("learning rate = {}, learning rate decay = {}, hidden size = {}, batch size = {}"
                      .format(10**lr, lr_decay, hs, bs))
                nn = TwoLayerNet(input_size, hs, num_classes)
                stats = nn.train(X_train, y_train, X_val, y_val,
                           num_iters=1000, batch_size=bs,
                           learning_rate=10**lr, learning_rate_decay=lr_decay,
                           reg=0.25, verbose=True)
                val_acc = (nn.predict(X_val) == y_val).mean()
                if val_acc > best_acc:
                    best_acc = val_acc
                    best_net = nn
                print("validation accuracy = %.4f" % val_acc)

            
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# learning rate = 0.0001, learning rate decay = 0.9, hidden size = 50, batch size = 32
# iteration 0 / 1000: loss 2.302743
# iteration 100 / 1000: loss 2.302215
# iteration 200 / 1000: loss 2.297624
# iteration 300 / 1000: loss 2.292134
# iteration 400 / 1000: loss 2.173218
# iteration 500 / 1000: loss 2.116098
# iteration 600 / 1000: loss 2.064633
# iteration 700 / 1000: loss 1.787757
# iteration 800 / 1000: loss 2.010593
# iteration 900 / 1000: loss 1.986494
# validation accuracy = 0.2790
# learning rate = 0.0001, learning rate decay = 0.9, hidden size = 50, batch size = 64
# iteration 0 / 1000: loss 2.302806
# iteration 100 / 1000: loss 2.302542
# iteration 200 / 1000: loss 2.301073
# iteration 300 / 1000: loss 2.280530
# iteration 400 / 1000: loss 2.234865
# iteration 500 / 1000: loss 2.040747
# iteration 600 / 1000: loss 2.073129
# iteration 700 / 1000: loss 2.017180
# iteration 800 / 1000: loss 1.940470
# iteration 900 / 1000: loss 1.945699
# validation accuracy = 0.2790
# learning rate = 0.0001, learning rate decay = 0.9, hidden size = 50, batch size = 128
# iteration 0 / 1000: loss 2.302770
# iteration 100 / 1000: loss 2.302267
# iteration 200 / 1000: loss 2.299467
# iteration 300 / 1000: loss 2.276528
# iteration 400 / 1000: loss 2.213367
# iteration 500 / 1000: loss 2.090432
# iteration 600 / 1000: loss 2.106628
# iteration 700 / 1000: loss 2.110690
# iteration 800 / 1000: loss 1.931412
# iteration 900 / 1000: loss 1.907119
# validation accuracy = 0.2810
# learning rate = 0.0001, learning rate decay = 0.9, hidden size = 100, batch size = 32
# iteration 0 / 1000: loss 2.303040
# iteration 100 / 1000: loss 2.302445
# iteration 200 / 1000: loss 2.297827
# iteration 300 / 1000: loss 2.205367
# iteration 400 / 1000: loss 2.159908
# iteration 500 / 1000: loss 2.031445
# iteration 600 / 1000: loss 2.087988
# iteration 700 / 1000: loss 1.919693
# iteration 800 / 1000: loss 2.162295
# iteration 900 / 1000: loss 1.899121
# validation accuracy = 0.3010
# learning rate = 0.0001, learning rate decay = 0.9, hidden size = 100, batch size = 64
# iteration 0 / 1000: loss 2.302955
# iteration 100 / 1000: loss 2.301795
# iteration 200 / 1000: loss 2.296973
# iteration 300 / 1000: loss 2.254380
# iteration 400 / 1000: loss 2.224149
# iteration 500 / 1000: loss 2.094687
# iteration 600 / 1000: loss 2.094881
# iteration 700 / 1000: loss 2.032522
# iteration 800 / 1000: loss 2.128242
# iteration 900 / 1000: loss 1.858253
# validation accuracy = 0.2970
# learning rate = 0.0001, learning rate decay = 0.9, hidden size = 100, batch size = 128
# iteration 0 / 1000: loss 2.302982
# iteration 100 / 1000: loss 2.302188
# iteration 200 / 1000: loss 2.297047
# iteration 300 / 1000: loss 2.244738
# iteration 400 / 1000: loss 2.194741
# iteration 500 / 1000: loss 2.094637
# iteration 600 / 1000: loss 2.128602
# iteration 700 / 1000: loss 2.042799
# iteration 800 / 1000: loss 1.924653
# iteration 900 / 1000: loss 2.050608
# validation accuracy = 0.2920
# learning rate = 0.0001, learning rate decay = 0.9, hidden size = 200, batch size = 32
# iteration 0 / 1000: loss 2.303319
# iteration 100 / 1000: loss 2.302095
# iteration 200 / 1000: loss 2.292876
# iteration 300 / 1000: loss 2.223991
# iteration 400 / 1000: loss 2.218662
# iteration 500 / 1000: loss 1.981440
# iteration 600 / 1000: loss 2.173097
# iteration 700 / 1000: loss 1.921491
# iteration 800 / 1000: loss 1.932797
# iteration 900 / 1000: loss 2.062370
# validation accuracy = 0.3010
# learning rate = 0.0001, learning rate decay = 0.9, hidden size = 200, batch size = 64
# iteration 0 / 1000: loss 2.303349
# iteration 100 / 1000: loss 2.301832
# iteration 200 / 1000: loss 2.284673
# iteration 300 / 1000: loss 2.238912
# iteration 400 / 1000: loss 2.197963
# iteration 500 / 1000: loss 2.134247
# iteration 600 / 1000: loss 2.038487
# iteration 700 / 1000: loss 2.063972
# iteration 800 / 1000: loss 1.881390
# iteration 900 / 1000: loss 1.992283
# validation accuracy = 0.3080
# learning rate = 0.0001, learning rate decay = 0.9, hidden size = 200, batch size = 128
# iteration 0 / 1000: loss 2.303350
# iteration 100 / 1000: loss 2.301511
# iteration 200 / 1000: loss 2.290283
# iteration 300 / 1000: loss 2.218193
# iteration 400 / 1000: loss 2.128445
# iteration 500 / 1000: loss 2.116982
# iteration 600 / 1000: loss 2.059146
# iteration 700 / 1000: loss 2.055027
# iteration 800 / 1000: loss 2.005378
# iteration 900 / 1000: loss 1.919592
# validation accuracy = 0.3100
# learning rate = 0.0001, learning rate decay = 0.99, hidden size = 50, batch size = 32
# iteration 0 / 1000: loss 2.302778
# iteration 100 / 1000: loss 2.302359
# iteration 200 / 1000: loss 2.299315
# iteration 300 / 1000: loss 2.286616
# iteration 400 / 1000: loss 2.198545
# iteration 500 / 1000: loss 2.115664
# iteration 600 / 1000: loss 1.945283
# iteration 700 / 1000: loss 2.328658
# iteration 800 / 1000: loss 1.890948
# iteration 900 / 1000: loss 1.955368
# validation accuracy = 0.2980
# learning rate = 0.0001, learning rate decay = 0.99, hidden size = 50, batch size = 64
# iteration 0 / 1000: loss 2.302821
# iteration 100 / 1000: loss 2.302354
# iteration 200 / 1000: loss 2.295302
# iteration 300 / 1000: loss 2.246668
# iteration 400 / 1000: loss 2.138132
# iteration 500 / 1000: loss 2.099162
# iteration 600 / 1000: loss 2.128660
# iteration 700 / 1000: loss 1.989376
# iteration 800 / 1000: loss 1.980216
# iteration 900 / 1000: loss 1.947206
# validation accuracy = 0.2970
# learning rate = 0.0001, learning rate decay = 0.99, hidden size = 50, batch size = 128
# iteration 0 / 1000: loss 2.302792
# iteration 100 / 1000: loss 2.302308
# iteration 200 / 1000: loss 2.294169
# iteration 300 / 1000: loss 2.208033
# iteration 400 / 1000: loss 2.137040
# iteration 500 / 1000: loss 2.127304
# iteration 600 / 1000: loss 2.117160
# iteration 700 / 1000: loss 2.063203
# iteration 800 / 1000: loss 1.932919
# iteration 900 / 1000: loss 1.839409
# validation accuracy = 0.2970
# learning rate = 0.0001, learning rate decay = 0.99, hidden size = 100, batch size = 32
# iteration 0 / 1000: loss 2.303005
# iteration 100 / 1000: loss 2.301799
# iteration 200 / 1000: loss 2.304878
# iteration 300 / 1000: loss 2.206107
# iteration 400 / 1000: loss 2.160265
# iteration 500 / 1000: loss 2.275054
# iteration 600 / 1000: loss 2.082797
# iteration 700 / 1000: loss 2.106390
# iteration 800 / 1000: loss 2.117143
# iteration 900 / 1000: loss 2.167154
# validation accuracy = 0.3120
# learning rate = 0.0001, learning rate decay = 0.99, hidden size = 100, batch size = 64
# iteration 0 / 1000: loss 2.302914
# iteration 100 / 1000: loss 2.301464
# iteration 200 / 1000: loss 2.289308
# iteration 300 / 1000: loss 2.263842
# iteration 400 / 1000: loss 2.244239
# iteration 500 / 1000: loss 2.115256
# iteration 600 / 1000: loss 2.020753
# iteration 700 / 1000: loss 2.026060
# iteration 800 / 1000: loss 2.036617
# iteration 900 / 1000: loss 1.838781
# validation accuracy = 0.3120
# learning rate = 0.0001, learning rate decay = 0.99, hidden size = 100, batch size = 128
# iteration 0 / 1000: loss 2.302907
# iteration 100 / 1000: loss 2.301756
# iteration 200 / 1000: loss 2.287699
# iteration 300 / 1000: loss 2.217997
# iteration 400 / 1000: loss 2.133918
# iteration 500 / 1000: loss 2.081781
# iteration 600 / 1000: loss 2.016342
# iteration 700 / 1000: loss 2.000251
# iteration 800 / 1000: loss 1.969581
# iteration 900 / 1000: loss 2.014283
# validation accuracy = 0.3090
# learning rate = 0.0001, learning rate decay = 0.99, hidden size = 200, batch size = 32
# iteration 0 / 1000: loss 2.303367
# iteration 100 / 1000: loss 2.301848
# iteration 200 / 1000: loss 2.271100
# iteration 300 / 1000: loss 2.175268
# iteration 400 / 1000: loss 2.234436
# iteration 500 / 1000: loss 2.181020
# iteration 600 / 1000: loss 2.045354
# iteration 700 / 1000: loss 1.915254
# iteration 800 / 1000: loss 2.046379
# iteration 900 / 1000: loss 1.849483
# validation accuracy = 0.3100
# learning rate = 0.0001, learning rate decay = 0.99, hidden size = 200, batch size = 64
# iteration 0 / 1000: loss 2.303357
# iteration 100 / 1000: loss 2.301672
# iteration 200 / 1000: loss 2.280565
# iteration 300 / 1000: loss 2.258243
# iteration 400 / 1000: loss 2.053929
# iteration 500 / 1000: loss 2.123789
# iteration 600 / 1000: loss 2.036904
# iteration 700 / 1000: loss 1.939764
# iteration 800 / 1000: loss 1.902387
# iteration 900 / 1000: loss 2.020019
# validation accuracy = 0.3170
# learning rate = 0.0001, learning rate decay = 0.99, hidden size = 200, batch size = 128
# iteration 0 / 1000: loss 2.303383
# iteration 100 / 1000: loss 2.301004
# iteration 200 / 1000: loss 2.277007
# iteration 300 / 1000: loss 2.195558
# iteration 400 / 1000: loss 2.106711
# iteration 500 / 1000: loss 2.114412
# iteration 600 / 1000: loss 2.053880
# iteration 700 / 1000: loss 2.011138
# iteration 800 / 1000: loss 1.924538
# iteration 900 / 1000: loss 1.971219
# validation accuracy = 0.3100
# learning rate = 0.0001, learning rate decay = 0.999, hidden size = 50, batch size = 32
# iteration 0 / 1000: loss 2.302730
# iteration 100 / 1000: loss 2.302143
# iteration 200 / 1000: loss 2.299304
# iteration 300 / 1000: loss 2.218489
# iteration 400 / 1000: loss 2.250518
# iteration 500 / 1000: loss 2.070250
# iteration 600 / 1000: loss 2.022667
# iteration 700 / 1000: loss 1.829901
# iteration 800 / 1000: loss 1.889597
# iteration 900 / 1000: loss 1.717848
# validation accuracy = 0.2870
# learning rate = 0.0001, learning rate decay = 0.999, hidden size = 50, batch size = 64
# iteration 0 / 1000: loss 2.302800
# iteration 100 / 1000: loss 2.302498
# iteration 200 / 1000: loss 2.300139
# iteration 300 / 1000: loss 2.265529
# iteration 400 / 1000: loss 2.228343
# iteration 500 / 1000: loss 2.020305
# iteration 600 / 1000: loss 1.996889
# iteration 700 / 1000: loss 2.005497
# iteration 800 / 1000: loss 1.938726
# iteration 900 / 1000: loss 1.959841
# validation accuracy = 0.2960
# learning rate = 0.0001, learning rate decay = 0.999, hidden size = 50, batch size = 128
# iteration 0 / 1000: loss 2.302782
# iteration 100 / 1000: loss 2.302470
# iteration 200 / 1000: loss 2.296871
# iteration 300 / 1000: loss 2.275453
# iteration 400 / 1000: loss 2.169132
# iteration 500 / 1000: loss 2.060739
# iteration 600 / 1000: loss 2.026021
# iteration 700 / 1000: loss 2.061255
# iteration 800 / 1000: loss 1.934621
# iteration 900 / 1000: loss 2.042357
# validation accuracy = 0.2910
# learning rate = 0.0001, learning rate decay = 0.999, hidden size = 100, batch size = 32
# iteration 0 / 1000: loss 2.302942
# iteration 100 / 1000: loss 2.302444
# iteration 200 / 1000: loss 2.298095
# iteration 300 / 1000: loss 2.263327
# iteration 400 / 1000: loss 2.111641
# iteration 500 / 1000: loss 2.095312
# iteration 600 / 1000: loss 1.906956
# iteration 700 / 1000: loss 2.025406
# iteration 800 / 1000: loss 2.112749
# iteration 900 / 1000: loss 1.833116
# validation accuracy = 0.3040
# learning rate = 0.0001, learning rate decay = 0.999, hidden size = 100, batch size = 64
# iteration 0 / 1000: loss 2.302996
# iteration 100 / 1000: loss 2.301793
# iteration 200 / 1000: loss 2.288803
# iteration 300 / 1000: loss 2.187330
# iteration 400 / 1000: loss 2.136827
# iteration 500 / 1000: loss 2.232518
# iteration 600 / 1000: loss 1.976463
# iteration 700 / 1000: loss 1.931495
# iteration 800 / 1000: loss 1.982544
# iteration 900 / 1000: loss 1.853955
# validation accuracy = 0.3010
# learning rate = 0.0001, learning rate decay = 0.999, hidden size = 100, batch size = 128
# iteration 0 / 1000: loss 2.302946
# iteration 100 / 1000: loss 2.301955
# iteration 200 / 1000: loss 2.292260
# iteration 300 / 1000: loss 2.236450
# iteration 400 / 1000: loss 2.181077
# iteration 500 / 1000: loss 2.106774
# iteration 600 / 1000: loss 2.039238
# iteration 700 / 1000: loss 1.948928
# iteration 800 / 1000: loss 2.015035
# iteration 900 / 1000: loss 1.897075
# validation accuracy = 0.3130
# learning rate = 0.0001, learning rate decay = 0.999, hidden size = 200, batch size = 32
# iteration 0 / 1000: loss 2.303340
# iteration 100 / 1000: loss 2.300876
# iteration 200 / 1000: loss 2.294029
# iteration 300 / 1000: loss 2.297257
# iteration 400 / 1000: loss 1.938591
# iteration 500 / 1000: loss 2.075548
# iteration 600 / 1000: loss 1.962670
# iteration 700 / 1000: loss 1.991857
# iteration 800 / 1000: loss 1.978761
# iteration 900 / 1000: loss 2.085982
# validation accuracy = 0.3070
# learning rate = 0.0001, learning rate decay = 0.999, hidden size = 200, batch size = 64
# iteration 0 / 1000: loss 2.303277
# iteration 100 / 1000: loss 2.300443
# iteration 200 / 1000: loss 2.278255
# iteration 300 / 1000: loss 2.293141
# iteration 400 / 1000: loss 2.136763
# iteration 500 / 1000: loss 2.170189
# iteration 600 / 1000: loss 2.071305
# iteration 700 / 1000: loss 2.097915
# iteration 800 / 1000: loss 1.748823
# iteration 900 / 1000: loss 2.020391
# validation accuracy = 0.3190
# learning rate = 0.0001, learning rate decay = 0.999, hidden size = 200, batch size = 128
# iteration 0 / 1000: loss 2.303331
# iteration 100 / 1000: loss 2.301618
# iteration 200 / 1000: loss 2.288752
# iteration 300 / 1000: loss 2.191258
# iteration 400 / 1000: loss 2.111758
# iteration 500 / 1000: loss 2.113949
# iteration 600 / 1000: loss 2.055201
# iteration 700 / 1000: loss 1.959398
# iteration 800 / 1000: loss 1.930272
# iteration 900 / 1000: loss 1.796080
# validation accuracy = 0.3190
# learning rate = 0.001, learning rate decay = 0.9, hidden size = 50, batch size = 32
# iteration 0 / 1000: loss 2.302772
# iteration 100 / 1000: loss 1.909411
# iteration 200 / 1000: loss 2.071295
# iteration 300 / 1000: loss 1.962992
# iteration 400 / 1000: loss 1.965390
# iteration 500 / 1000: loss 1.566792
# iteration 600 / 1000: loss 1.921478
# iteration 700 / 1000: loss 1.449997
# iteration 800 / 1000: loss 1.796531
# iteration 900 / 1000: loss 1.582716
# validation accuracy = 0.3830
# learning rate = 0.001, learning rate decay = 0.9, hidden size = 50, batch size = 64
# iteration 0 / 1000: loss 2.302777
# iteration 100 / 1000: loss 1.880655
# iteration 200 / 1000: loss 1.802001
# iteration 300 / 1000: loss 1.622888
# iteration 400 / 1000: loss 1.575826
# iteration 500 / 1000: loss 1.604945
# iteration 600 / 1000: loss 1.698054
# iteration 700 / 1000: loss 1.764948
# iteration 800 / 1000: loss 1.672341
# iteration 900 / 1000: loss 1.509076
# validation accuracy = 0.4190
# learning rate = 0.001, learning rate decay = 0.9, hidden size = 50, batch size = 128
# iteration 0 / 1000: loss 2.302798
# iteration 100 / 1000: loss 1.978259
# iteration 200 / 1000: loss 1.783731
# iteration 300 / 1000: loss 1.745759
# iteration 400 / 1000: loss 1.730258
# iteration 500 / 1000: loss 1.573909
# iteration 600 / 1000: loss 1.636317
# iteration 700 / 1000: loss 1.595772
# iteration 800 / 1000: loss 1.592170
# iteration 900 / 1000: loss 1.638575
# validation accuracy = 0.4630
# learning rate = 0.001, learning rate decay = 0.9, hidden size = 100, batch size = 32
# iteration 0 / 1000: loss 2.303027
# iteration 100 / 1000: loss 1.886410
# iteration 200 / 1000: loss 1.876693
# iteration 300 / 1000: loss 1.560578
# iteration 400 / 1000: loss 1.760305
# iteration 500 / 1000: loss 2.021931
# iteration 600 / 1000: loss 1.464582
# iteration 700 / 1000: loss 2.104414
# iteration 800 / 1000: loss 2.124482
# iteration 900 / 1000: loss 1.771213
# validation accuracy = 0.3820
# learning rate = 0.001, learning rate decay = 0.9, hidden size = 100, batch size = 64
# iteration 0 / 1000: loss 2.302964
# iteration 100 / 1000: loss 1.899693
# iteration 200 / 1000: loss 1.733842
# iteration 300 / 1000: loss 1.845648
# iteration 400 / 1000: loss 1.594539
# iteration 500 / 1000: loss 1.427485
# iteration 600 / 1000: loss 1.687930
# iteration 700 / 1000: loss 1.548355
# iteration 800 / 1000: loss 1.483501
# iteration 900 / 1000: loss 1.772152
# validation accuracy = 0.4610
# learning rate = 0.001, learning rate decay = 0.9, hidden size = 100, batch size = 128
# iteration 0 / 1000: loss 2.303011
# iteration 100 / 1000: loss 1.971927
# iteration 200 / 1000: loss 1.778487
# iteration 300 / 1000: loss 1.717290
# iteration 400 / 1000: loss 1.583062
# iteration 500 / 1000: loss 1.582798
# iteration 600 / 1000: loss 1.480986
# iteration 700 / 1000: loss 1.535516
# iteration 800 / 1000: loss 1.635783
# iteration 900 / 1000: loss 1.517873
# validation accuracy = 0.4730
# learning rate = 0.001, learning rate decay = 0.9, hidden size = 200, batch size = 32
# iteration 0 / 1000: loss 2.303358
# iteration 100 / 1000: loss 2.049233
# iteration 200 / 1000: loss 1.714546
# iteration 300 / 1000: loss 1.896715
# iteration 400 / 1000: loss 1.646783
# iteration 500 / 1000: loss 1.716634
# iteration 600 / 1000: loss 1.726862
# iteration 700 / 1000: loss 1.548163
# iteration 800 / 1000: loss 1.353643
# iteration 900 / 1000: loss 1.744356
# validation accuracy = 0.3920
# learning rate = 0.001, learning rate decay = 0.9, hidden size = 200, batch size = 64
# iteration 0 / 1000: loss 2.303325
# iteration 100 / 1000: loss 1.892251
# iteration 200 / 1000: loss 1.847015
# iteration 300 / 1000: loss 2.129054
# iteration 400 / 1000: loss 1.720841
# iteration 500 / 1000: loss 1.372636
# iteration 600 / 1000: loss 1.868085
# iteration 700 / 1000: loss 1.666194
# iteration 800 / 1000: loss 1.438129
# iteration 900 / 1000: loss 1.875438
# validation accuracy = 0.4100
# learning rate = 0.001, learning rate decay = 0.9, hidden size = 200, batch size = 128
# iteration 0 / 1000: loss 2.303301
# iteration 100 / 1000: loss 1.894345
# iteration 200 / 1000: loss 1.790903
# iteration 300 / 1000: loss 1.683279
# iteration 400 / 1000: loss 1.531603
# iteration 500 / 1000: loss 1.502303
# iteration 600 / 1000: loss 1.565227
# iteration 700 / 1000: loss 1.351017
# iteration 800 / 1000: loss 1.454505
# iteration 900 / 1000: loss 1.565732
# validation accuracy = 0.4770
# learning rate = 0.001, learning rate decay = 0.99, hidden size = 50, batch size = 32
# iteration 0 / 1000: loss 2.302802
# iteration 100 / 1000: loss 1.984358
# iteration 200 / 1000: loss 1.744754
# iteration 300 / 1000: loss 1.916591
# iteration 400 / 1000: loss 2.071681
# iteration 500 / 1000: loss 1.913611
# iteration 600 / 1000: loss 1.655639
# iteration 700 / 1000: loss 1.477416
# iteration 800 / 1000: loss 1.908636
# iteration 900 / 1000: loss 1.687021
# validation accuracy = 0.3900
# learning rate = 0.001, learning rate decay = 0.99, hidden size = 50, batch size = 64
# iteration 0 / 1000: loss 2.302811
# iteration 100 / 1000: loss 1.925176
# iteration 200 / 1000: loss 1.797774
# iteration 300 / 1000: loss 1.757004
# iteration 400 / 1000: loss 1.684973
# iteration 500 / 1000: loss 1.486967
# iteration 600 / 1000: loss 1.819111
# iteration 700 / 1000: loss 1.944549
# iteration 800 / 1000: loss 1.543548
# iteration 900 / 1000: loss 1.834547
# validation accuracy = 0.4450
# learning rate = 0.001, learning rate decay = 0.99, hidden size = 50, batch size = 128
# iteration 0 / 1000: loss 2.302753
# iteration 100 / 1000: loss 1.953894
# iteration 200 / 1000: loss 1.781415
# iteration 300 / 1000: loss 1.690660
# iteration 400 / 1000: loss 1.570477
# iteration 500 / 1000: loss 1.563747
# iteration 600 / 1000: loss 1.634268
# iteration 700 / 1000: loss 1.648549
# iteration 800 / 1000: loss 1.432669
# iteration 900 / 1000: loss 1.534981
# validation accuracy = 0.4690
# learning rate = 0.001, learning rate decay = 0.99, hidden size = 100, batch size = 32
# iteration 0 / 1000: loss 2.302975
# iteration 100 / 1000: loss 1.874612
# iteration 200 / 1000: loss 1.809743
# iteration 300 / 1000: loss 1.886204
# iteration 400 / 1000: loss 1.727846
# iteration 500 / 1000: loss 1.804861
# iteration 600 / 1000: loss 1.563916
# iteration 700 / 1000: loss 1.558477
# iteration 800 / 1000: loss 1.914513
# iteration 900 / 1000: loss 1.657868
# validation accuracy = 0.3510
# learning rate = 0.001, learning rate decay = 0.99, hidden size = 100, batch size = 64
# iteration 0 / 1000: loss 2.302950
# iteration 100 / 1000: loss 1.950164
# iteration 200 / 1000: loss 1.682714
# iteration 300 / 1000: loss 1.580685
# iteration 400 / 1000: loss 1.541324
# iteration 500 / 1000: loss 1.680186
# iteration 600 / 1000: loss 1.885265
# iteration 700 / 1000: loss 1.492791
# iteration 800 / 1000: loss 1.780108
# iteration 900 / 1000: loss 1.966478
# validation accuracy = 0.4270
# learning rate = 0.001, learning rate decay = 0.99, hidden size = 100, batch size = 128
# iteration 0 / 1000: loss 2.302951
# iteration 100 / 1000: loss 1.943039
# iteration 200 / 1000: loss 1.721799
# iteration 300 / 1000: loss 1.751236
# iteration 400 / 1000: loss 1.594775
# iteration 500 / 1000: loss 1.785757
# iteration 600 / 1000: loss 1.662034
# iteration 700 / 1000: loss 1.649458
# iteration 800 / 1000: loss 1.689952
# iteration 900 / 1000: loss 1.600904
# validation accuracy = 0.4560
# learning rate = 0.001, learning rate decay = 0.99, hidden size = 200, batch size = 32
# iteration 0 / 1000: loss 2.303406
# iteration 100 / 1000: loss 1.927822
# iteration 200 / 1000: loss 1.736785
# iteration 300 / 1000: loss 1.929560
# iteration 400 / 1000: loss 1.696900
# iteration 500 / 1000: loss 1.484555
# iteration 600 / 1000: loss 1.925994
# iteration 700 / 1000: loss 1.999137
# iteration 800 / 1000: loss 1.823944
# iteration 900 / 1000: loss 1.373832
# validation accuracy = 0.3960
# learning rate = 0.001, learning rate decay = 0.99, hidden size = 200, batch size = 64
# iteration 0 / 1000: loss 2.303369
# iteration 100 / 1000: loss 1.936473
# iteration 200 / 1000: loss 1.825751
# iteration 300 / 1000: loss 1.717483
# iteration 400 / 1000: loss 1.885247
# iteration 500 / 1000: loss 1.691991
# iteration 600 / 1000: loss 1.685723
# iteration 700 / 1000: loss 1.712270
# iteration 800 / 1000: loss 1.370969
# iteration 900 / 1000: loss 1.294640
# validation accuracy = 0.4200
# learning rate = 0.001, learning rate decay = 0.99, hidden size = 200, batch size = 128
# iteration 0 / 1000: loss 2.303367
# iteration 100 / 1000: loss 1.873514
# iteration 200 / 1000: loss 1.761994
# iteration 300 / 1000: loss 1.621751
# iteration 400 / 1000: loss 1.469053
# iteration 500 / 1000: loss 1.595651
# iteration 600 / 1000: loss 1.488636
# iteration 700 / 1000: loss 1.456450
# iteration 800 / 1000: loss 1.454076
# iteration 900 / 1000: loss 1.545137
# validation accuracy = 0.4630
# learning rate = 0.001, learning rate decay = 0.999, hidden size = 50, batch size = 32
# iteration 0 / 1000: loss 2.302753
# iteration 100 / 1000: loss 2.145783
# iteration 200 / 1000: loss 1.882993
# iteration 300 / 1000: loss 2.000140
# iteration 400 / 1000: loss 1.853051
# iteration 500 / 1000: loss 1.591227
# iteration 600 / 1000: loss 1.982348
# iteration 700 / 1000: loss 1.562665
# iteration 800 / 1000: loss 1.760450
# iteration 900 / 1000: loss 1.801755
# validation accuracy = 0.4100
# learning rate = 0.001, learning rate decay = 0.999, hidden size = 50, batch size = 64
# iteration 0 / 1000: loss 2.302756
# iteration 100 / 1000: loss 2.264567
# iteration 200 / 1000: loss 1.884307
# iteration 300 / 1000: loss 1.760477
# iteration 400 / 1000: loss 1.701793
# iteration 500 / 1000: loss 1.785944
# iteration 600 / 1000: loss 1.513432
# iteration 700 / 1000: loss 1.639947
# iteration 800 / 1000: loss 1.408878
# iteration 900 / 1000: loss 1.733933
# validation accuracy = 0.4420
# learning rate = 0.001, learning rate decay = 0.999, hidden size = 50, batch size = 128
# iteration 0 / 1000: loss 2.302768
# iteration 100 / 1000: loss 1.964827
# iteration 200 / 1000: loss 1.851070
# iteration 300 / 1000: loss 1.580998
# iteration 400 / 1000: loss 1.733915
# iteration 500 / 1000: loss 1.652122
# iteration 600 / 1000: loss 1.602297
# iteration 700 / 1000: loss 1.631173
# iteration 800 / 1000: loss 1.521545
# iteration 900 / 1000: loss 1.476735
# validation accuracy = 0.4600
# learning rate = 0.001, learning rate decay = 0.999, hidden size = 100, batch size = 32
# iteration 0 / 1000: loss 2.302959
# iteration 100 / 1000: loss 1.976360
# iteration 200 / 1000: loss 1.708366
# iteration 300 / 1000: loss 1.963303
# iteration 400 / 1000: loss 1.455322
# iteration 500 / 1000: loss 1.913430
# iteration 600 / 1000: loss 1.782471
# iteration 700 / 1000: loss 1.796274
# iteration 800 / 1000: loss 1.823258
# iteration 900 / 1000: loss 1.536842
# validation accuracy = 0.3840
# learning rate = 0.001, learning rate decay = 0.999, hidden size = 100, batch size = 64
# iteration 0 / 1000: loss 2.302995
# iteration 100 / 1000: loss 2.088096
# iteration 200 / 1000: loss 1.937206
# iteration 300 / 1000: loss 1.672423
# iteration 400 / 1000: loss 1.671072
# iteration 500 / 1000: loss 1.445888
# iteration 600 / 1000: loss 1.521303
# iteration 700 / 1000: loss 1.694744
# iteration 800 / 1000: loss 1.651521
# iteration 900 / 1000: loss 1.777384
# validation accuracy = 0.4330
# learning rate = 0.001, learning rate decay = 0.999, hidden size = 100, batch size = 128
# iteration 0 / 1000: loss 2.303005
# iteration 100 / 1000: loss 1.975843
# iteration 200 / 1000: loss 1.839117
# iteration 300 / 1000: loss 1.821916
# iteration 400 / 1000: loss 1.713970
# iteration 500 / 1000: loss 1.546015
# iteration 600 / 1000: loss 1.578718
# iteration 700 / 1000: loss 1.475572
# iteration 800 / 1000: loss 1.491099
# iteration 900 / 1000: loss 1.540530
# validation accuracy = 0.4710
# learning rate = 0.001, learning rate decay = 0.999, hidden size = 200, batch size = 32
# iteration 0 / 1000: loss 2.303387
# iteration 100 / 1000: loss 1.892799
# iteration 200 / 1000: loss 1.989298
# iteration 300 / 1000: loss 1.833558
# iteration 400 / 1000: loss 1.720330
# iteration 500 / 1000: loss 1.707788
# iteration 600 / 1000: loss 1.868153
# iteration 700 / 1000: loss 1.917107
# iteration 800 / 1000: loss 1.585111
# iteration 900 / 1000: loss 1.801580
# validation accuracy = 0.3850
# learning rate = 0.001, learning rate decay = 0.999, hidden size = 200, batch size = 64
# iteration 0 / 1000: loss 2.303370
# iteration 100 / 1000: loss 2.073792
# iteration 200 / 1000: loss 1.849880
# iteration 300 / 1000: loss 1.530727
# iteration 400 / 1000: loss 1.645738
# iteration 500 / 1000: loss 1.581490
# iteration 600 / 1000: loss 1.696738
# iteration 700 / 1000: loss 1.231571
# iteration 800 / 1000: loss 1.836774
# iteration 900 / 1000: loss 1.441378
# validation accuracy = 0.4420
# learning rate = 0.001, learning rate decay = 0.999, hidden size = 200, batch size = 128
# iteration 0 / 1000: loss 2.303308
# iteration 100 / 1000: loss 1.814265
# iteration 200 / 1000: loss 1.693475
# iteration 300 / 1000: loss 1.655063
# iteration 400 / 1000: loss 1.627620
# iteration 500 / 1000: loss 1.503104
# iteration 600 / 1000: loss 1.572381
# iteration 700 / 1000: loss 1.611899
# iteration 800 / 1000: loss 1.618950
# iteration 900 / 1000: loss 1.495246
# validation accuracy = 0.4480
# learning rate = 0.01, learning rate decay = 0.9, hidden size = 50, batch size = 32
# iteration 0 / 1000: loss 2.302770
# /home/fhz/Desktop/Machine Learning/CS231n/Assignment/Assignment 1/cs231n/classifiers/neural_net.py:102: RuntimeWarning: invalid value encountered in true_divide
#   loss = np.sum(-np.log(numerator / denominator))
# /home/fhz/Desktop/Machine Learning/CS231n/Assignment/Assignment 1/cs231n/classifiers/neural_net.py:102: RuntimeWarning: divide by zero encountered in log
#   loss = np.sum(-np.log(numerator / denominator))
# /home/fhz/Desktop/Machine Learning/CS231n/Assignment/Assignment 1/cs231n/classifiers/neural_net.py:116: RuntimeWarning: invalid value encountered in true_divide
#   dscores = dloss * np.exp(scores) / denominator
# /home/fhz/Desktop/Machine Learning/CS231n/Assignment/Assignment 1/cs231n/classifiers/neural_net.py:122: RuntimeWarning: invalid value encountered in less
#   dh_a[h < 0] = 0
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.9, hidden size = 50, batch size = 64
# iteration 0 / 1000: loss 2.302737
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.9, hidden size = 50, batch size = 128
# iteration 0 / 1000: loss 2.302763
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.9, hidden size = 100, batch size = 32
# iteration 0 / 1000: loss 2.302978
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.9, hidden size = 100, batch size = 64
# iteration 0 / 1000: loss 2.302994
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.9, hidden size = 100, batch size = 128
# iteration 0 / 1000: loss 2.302962
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.9, hidden size = 200, batch size = 32
# iteration 0 / 1000: loss 2.303345
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.9, hidden size = 200, batch size = 64
# iteration 0 / 1000: loss 2.303376
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.9, hidden size = 200, batch size = 128
# iteration 0 / 1000: loss 2.303404
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.99, hidden size = 50, batch size = 32
# iteration 0 / 1000: loss 2.302776
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.99, hidden size = 50, batch size = 64
# iteration 0 / 1000: loss 2.302778
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.99, hidden size = 50, batch size = 128
# iteration 0 / 1000: loss 2.302787
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.99, hidden size = 100, batch size = 32
# iteration 0 / 1000: loss 2.302975
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.99, hidden size = 100, batch size = 64
# iteration 0 / 1000: loss 2.302936
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.99, hidden size = 100, batch size = 128
# iteration 0 / 1000: loss 2.302971
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.99, hidden size = 200, batch size = 32
# iteration 0 / 1000: loss 2.303391
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.99, hidden size = 200, batch size = 64
# iteration 0 / 1000: loss 2.303380
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.99, hidden size = 200, batch size = 128
# iteration 0 / 1000: loss 2.303393
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.999, hidden size = 50, batch size = 32
# iteration 0 / 1000: loss 2.302819
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.999, hidden size = 50, batch size = 64
# iteration 0 / 1000: loss 2.302769
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.999, hidden size = 50, batch size = 128
# iteration 0 / 1000: loss 2.302762
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.999, hidden size = 100, batch size = 32
# iteration 0 / 1000: loss 2.302946
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.999, hidden size = 100, batch size = 64
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.999, hidden size = 100, batch size = 128
# iteration 0 / 1000: loss 2.302969
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.999, hidden size = 200, batch size = 32
# iteration 0 / 1000: loss 2.303378
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.999, hidden size = 200, batch size = 64
# iteration 0 / 1000: loss 2.303331
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.01, learning rate decay = 0.999, hidden size = 200, batch size = 128
# iteration 0 / 1000: loss 2.303330
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.9, hidden size = 50, batch size = 32
# iteration 0 / 1000: loss 2.302817
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.9, hidden size = 50, batch size = 64
# iteration 0 / 1000: loss 2.302769
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.9, hidden size = 50, batch size = 128
# iteration 0 / 1000: loss 2.302764
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.9, hidden size = 100, batch size = 32
# iteration 0 / 1000: loss 2.302958
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.9, hidden size = 100, batch size = 64
# iteration 0 / 1000: loss 2.302999
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.9, hidden size = 100, batch size = 128
# iteration 0 / 1000: loss 2.302947
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.9, hidden size = 200, batch size = 32
# iteration 0 / 1000: loss 2.303288
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.9, hidden size = 200, batch size = 64
# iteration 0 / 1000: loss 2.303310
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.9, hidden size = 200, batch size = 128
# iteration 0 / 1000: loss 2.303346
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.99, hidden size = 50, batch size = 32
# iteration 0 / 1000: loss 2.302735
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.99, hidden size = 50, batch size = 64
# iteration 0 / 1000: loss 2.302717
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.99, hidden size = 50, batch size = 128
# iteration 0 / 1000: loss 2.302781
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.99, hidden size = 100, batch size = 32
# iteration 0 / 1000: loss 2.302984
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.99, hidden size = 100, batch size = 64
# iteration 0 / 1000: loss 2.302947
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.99, hidden size = 100, batch size = 128
# iteration 0 / 1000: loss 2.302983
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.99, hidden size = 200, batch size = 32
# iteration 0 / 1000: loss 2.303403
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.99, hidden size = 200, batch size = 64
# iteration 0 / 1000: loss 2.303262
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.99, hidden size = 200, batch size = 128
# iteration 0 / 1000: loss 2.303291
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.999, hidden size = 50, batch size = 32
# iteration 0 / 1000: loss 2.302722
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.999, hidden size = 50, batch size = 64
# iteration 0 / 1000: loss 2.302810
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.999, hidden size = 50, batch size = 128
# iteration 0 / 1000: loss 2.302772
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.999, hidden size = 100, batch size = 32
# iteration 0 / 1000: loss 2.303038
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.999, hidden size = 100, batch size = 64
# iteration 0 / 1000: loss 2.302922
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.999, hidden size = 100, batch size = 128
# iteration 0 / 1000: loss 2.302940
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.999, hidden size = 200, batch size = 32
# iteration 0 / 1000: loss 2.303302
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.999, hidden size = 200, batch size = 64
# iteration 0 / 1000: loss 2.303256
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870
# learning rate = 0.1, learning rate decay = 0.999, hidden size = 200, batch size = 128
# iteration 0 / 1000: loss 2.303313
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# validation accuracy = 0.0870

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-26fd2799494b> in <module>
# ----> 1 test_acc = (best_net.predict(X_test) == y_test).mean()
#       2 print('Test accuracy: ', test_acc)
#
# NameError: name 'best_net' is not defined
